# %%
#IPL Analysis

#importing data using read_csv()
import numpy as np
import pandas as pd

# %%
pd.read_csv('matches.csv')
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 5      6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6      7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 7      8    2017         Indore  2017-04-10  Royal Challengers Bangalore
# 8      9    2017           Pune  2017-04-11             Delhi Daredevils
# 9     10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 10    11    2017        Kolkata  2017-04-13              Kings XI Punjab
# 11    12    2017      Bangalore  2017-04-14  Royal Challengers Bangalore
# ...

# %%
data=pd.read_csv('matches.csv')
data
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 5      6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6      7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 7      8    2017         Indore  2017-04-10  Royal Challengers Bangalore
# 8      9    2017           Pune  2017-04-11             Delhi Daredevils
# 9     10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 10    11    2017        Kolkata  2017-04-13              Kings XI Punjab
# 11    12    2017      Bangalore  2017-04-14  Royal Challengers Bangalore
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
#important functions and attributes in pandas

# %%
#fn for previewing data
#for datasets containing million rows .head() function takes out top 5 data and displays it..
#head() gives preview of the data and is very flexible as custom values can be passed onto it.
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.head(100)
#shows top 100 rows
#head(n) show top n rows
# Out:
#      id  season        city        date                        team1  \
# 0     1    2017   Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1     2    2017        Pune  2017-04-06               Mumbai Indians
# 2     3    2017      Rajkot  2017-04-07                Gujarat Lions
# 3     4    2017      Indore  2017-04-08       Rising Pune Supergiant
# 4     5    2017   Bangalore  2017-04-08  Royal Challengers Bangalore
# 5     6    2017   Hyderabad  2017-04-09                Gujarat Lions
# 6     7    2017      Mumbai  2017-04-09        Kolkata Knight Riders
# 7     8    2017      Indore  2017-04-10  Royal Challengers Bangalore
# 8     9    2017        Pune  2017-04-11             Delhi Daredevils
# 9    10    2017      Mumbai  2017-04-12          Sunrisers Hyderabad
# 10   11    2017     Kolkata  2017-04-13              Kings XI Punjab
# 11   12    2017   Bangalore  2017-04-14  Royal Challengers Bangalore
# 12   13    2017      Rajkot  2017-04-14       Rising Pune Supergiant
# ...

# %%
data.head(3)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07        Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# 2  normal           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue         umpire1  \
# ...

# %%
data.tail()
# Out:
#       id  season       city        date                team1  \
# 631  632    2016     Raipur  2016-05-22     Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24        Gujarat Lions
# 633  634    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27        Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %%
#complementary function for head()
#tail() function gives preview of rows of dataset from bottom.

# %%
data.tail(4)
# Out:
#       id  season       city        date                team1  \
# 632  633    2016  Bangalore  2016-05-24        Gujarat Lions
# 633  634    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27        Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 632  normal           0  Royal Challengers Bangalore            0
# 633  normal           0          Sunrisers Hyderabad           22
# 634  normal           0          Sunrisers Hyderabad            0
# ...

# %%
#attributes
    #shape is a attributes showing no.of rows and columns
    #row being the first one
data.shape
# Out:
# (636, 18)

# %%
data.shape[1]
#shows columns
# Out:
# 18

# %%
data.shape[0]
#shows rows
# Out:
# 636

# %%
#fn
    #gives a detailed brief preview on the data or the dataset
    #also it gives information about each column
    #pandas treat string as object.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
# id                 636 non-null int64
# season             636 non-null int64
# city               629 non-null object
# date               636 non-null object
# team1              636 non-null object
# team2              636 non-null object
# toss_winner        636 non-null object
# toss_decision      636 non-null object
# result             636 non-null object
# dl_applied         636 non-null int64
# winner             633 non-null object
# win_by_runs        636 non-null int64
# win_by_wickets     636 non-null int64
# player_of_match    633 non-null object
# venue              636 non-null object
# umpire1            635 non-null object
# umpire2            635 non-null object
# umpire3            0 non-null float64
# dtypes: float64(1), int64(5), object(12)
# memory usage: 89.5+ KB

# %%
#function describe
    #works only on numerical columns
    #provides high level mmathematical summary for the dataset
data.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
#fetching rows and columns from a given dataframe

# %%
data
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 5      6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6      7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 7      8    2017         Indore  2017-04-10  Royal Challengers Bangalore
# 8      9    2017           Pune  2017-04-11             Delhi Daredevils
# 9     10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 10    11    2017        Kolkata  2017-04-13              Kings XI Punjab
# 11    12    2017      Bangalore  2017-04-14  Royal Challengers Bangalore
# ...

# %%
#advantage-fetching out important set(s) columns/rows required for analysis
data['winner']
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
# 5              Sunrisers Hyderabad
# 6                   Mumbai Indians
# 7                  Kings XI Punjab
# 8                 Delhi Daredevils
# 9                   Mumbai Indians
# 10           Kolkata Knight Riders
# 11                  Mumbai Indians
# 12                   Gujarat Lions
# 13           Kolkata Knight Riders
# 14                Delhi Daredevils
# 15                  Mumbai Indians
# 16          Rising Pune Supergiant
# 17           Kolkata Knight Riders
# 18             Sunrisers Hyderabad
# 19     Royal Challengers Bangalore
# 20             Sunrisers Hyderabad
# 21                  Mumbai Indians
# 22                   Gujarat Lions
# 23                  Mumbai Indians
# 24          Rising Pune Supergiant
# 25                 Kings XI Punjab
# 26           Kolkata Knight Riders
# ...

# %%
type(data['winner'])
# Out:
# pandas.core.series.Series

# %%
#series contains index and values

# %%
#fetching out mmultiple columns
data[['team1','team2','winner']]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# 5                  Gujarat Lions          Sunrisers Hyderabad
# 6          Kolkata Knight Riders               Mumbai Indians
# 7    Royal Challengers Bangalore              Kings XI Punjab
# 8               Delhi Daredevils       Rising Pune Supergiant
# 9            Sunrisers Hyderabad               Mumbai Indians
# 10               Kings XI Punjab        Kolkata Knight Riders
# 11   Royal Challengers Bangalore               Mumbai Indians
# 12        Rising Pune Supergiant                Gujarat Lions
# 13         Kolkata Knight Riders          Sunrisers Hyderabad
# ...

# %%
#tabular form
type(data[['team1','team2','winner']])
# Out:
# pandas.core.frame.DataFrame

# %%
data[['team1','team2','winner']].shape
#shape of dataframe
# Out:
# (636, 3)

# %%
#shape of series
data['winner'].shape
#for adding single items in tuple single ,(comma)is required
# Out:
# (636,)

# %%
#iloc[n] function
#similaar to indexing
data.iloc[0]
#fetches out nth row
# Out:
# id                                                         1
# season                                                  2017
# city                                               Hyderabad
# date                                              2017-04-05
# team1                                    Sunrisers Hyderabad
# team2                            Royal Challengers Bangalore
# toss_winner                      Royal Challengers Bangalore
# toss_decision                                          field
# result                                                normal
# dl_applied                                                 0
# winner                                   Sunrisers Hyderabad
# win_by_runs                                               35
# win_by_wickets                                             0
# player_of_match                                 Yuvraj Singh
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %%
#for fetching 2nd row
data.iloc[1]
# Out:
# id                                                       2
# season                                                2017
# city                                                  Pune
# date                                            2017-04-06
# team1                                       Mumbai Indians
# team2                               Rising Pune Supergiant
# toss_winner                         Rising Pune Supergiant
# toss_decision                                        field
# result                                              normal
# dl_applied                                               0
# winner                              Rising Pune Supergiant
# win_by_runs                                              0
# win_by_wickets                                           7
# player_of_match                                  SPD Smith
# venue              Maharashtra Cricket Association Stadium
# umpire1                                     A Nand Kishore
# ...

# %%
#slicing can also be done using iloc[] funtion
data.iloc[1:3]
# Out:
#    id  season    city        date           team1                   team2  \
# 1   2    2017    Pune  2017-04-06  Mumbai Indians  Rising Pune Supergiant
# 2   3    2017  Rajkot  2017-04-07   Gujarat Lions   Kolkata Knight Riders
#
#               toss_winner toss_decision  result  dl_applied  \
# 1  Rising Pune Supergiant         field  normal           0
# 2   Kolkata Knight Riders         field  normal           0
#
#                    winner  win_by_runs  win_by_wickets player_of_match  \
# 1  Rising Pune Supergiant            0               7       SPD Smith
# 2   Kolkata Knight Riders            0              10         CA Lynn
#
#                                      venue         umpire1    umpire2  umpire3
# 1  Maharashtra Cricket Association Stadium  A Nand Kishore     S Ravi      NaN
# 2   Saurashtra Cricket Association Stadium     Nitin Menon  CK Nandan      NaN

# %%
type(data.iloc[1:3])
# Out:
# pandas.core.frame.DataFrame

# %%
data.iloc[1:11:2]
#data of the dataset indexed from 1 to 11 alternately,just like for loop...
# Out:
#    id  season       city        date                        team1  \
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                     team2                  toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant       Rising Pune Supergiant         field  normal
# 3         Kings XI Punjab              Kings XI Punjab         field  normal
# 5     Sunrisers Hyderabad          Sunrisers Hyderabad         field  normal
# 7         Kings XI Punjab  Royal Challengers Bangalore           bat  normal
# 9          Mumbai Indians               Mumbai Indians         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# ...

# %%
#data.iloc[m:n:o]
#m-starting point
#n-end point (excluded from index)
#o-stpes/skips

# %%
#error
data.iloc[1:5:6]
# Out:
#    id  season  city        date           team1                   team2  \
# 1   2    2017  Pune  2017-04-06  Mumbai Indians  Rising Pune Supergiant
#
#               toss_winner toss_decision  result  dl_applied  \
# 1  Rising Pune Supergiant         field  normal           0
#
#                    winner  win_by_runs  win_by_wickets player_of_match  \
# 1  Rising Pune Supergiant            0               7       SPD Smith
#
#                                      venue         umpire1 umpire2  umpire3
# 1  Maharashtra Cricket Association Stadium  A Nand Kishore  S Ravi      NaN

# %%
data.iloc[[1,5,6]]
#using the concept of fancy indexing from numpy
#fancy indexing is supported under iloc
# Out:
#    id  season       city        date                  team1  \
# 1   2    2017       Pune  2017-04-06         Mumbai Indians
# 5   6    2017  Hyderabad  2017-04-09          Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09  Kolkata Knight Riders
#
#                     team2             toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant  Rising Pune Supergiant         field  normal
# 5     Sunrisers Hyderabad     Sunrisers Hyderabad         field  normal
# 6          Mumbai Indians          Mumbai Indians         field  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1           0  Rising Pune Supergiant            0               7
# 5           0     Sunrisers Hyderabad            0               9
# 6           0          Mumbai Indians            0               4
#
#   player_of_match                                      venue         umpire1  \
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
# ...

# %%
#fetching columns usuing iloc
#data.iloc[description of row,description of column]
#data.iloc[:,]-prints out all the rows i.e rows are not excluded or are not skipped
data.iloc[:,[4,5,10]]
#using fancy indexing for columns part.....
#iloc is very powerful as it can be used for both fetching rows and columns and it also supports fancy indexing.
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# 5                  Gujarat Lions          Sunrisers Hyderabad
# 6          Kolkata Knight Riders               Mumbai Indians
# 7    Royal Challengers Bangalore              Kings XI Punjab
# 8               Delhi Daredevils       Rising Pune Supergiant
# 9            Sunrisers Hyderabad               Mumbai Indians
# 10               Kings XI Punjab        Kolkata Knight Riders
# 11   Royal Challengers Bangalore               Mumbai Indians
# 12        Rising Pune Supergiant                Gujarat Lions
# 13         Kolkata Knight Riders          Sunrisers Hyderabad
# ...

# %%
#Filtering dataframe (based) on a (given) condition or value:-masking using boolean series
data['city']=='Hyderabad'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18      True
# 19     False
# 20      True
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 606    False
# 607    False
# 608    False
# 609     True
# 610    False
# 611    False
# 612    False
# 613    False
# 614    False
# 615    False
# 616    False
# 617     True
# 618    False
# 619    False
# 620    False
# 621    False
# 622    False
# 623    False
# 624    False
# 625    False
# 626    False
# 627    False
# 628    False
# 629    False
# 630    False
# 631    False
# 632    False
# 633    False
# 634    False
# 635    False
# Name: city, Length: 636, dtype: bool

# %%
type(data['city']=='Hyderabad')
#special series-boolean series
#every value in this series is a boolean value
# Out:
# pandas.core.series.Series

# %%
mask=data['city']=='Hyderabad'

# %%
data[mask]
#just like boolean indexing in numpy
#a dataframe is obtained in which boolean value is true
#extracted the dataframe with city hhaving value=Hyderabad
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 5      6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 18    19    2017  Hyderabad  2017-04-17          Sunrisers Hyderabad
# 20    21    2017  Hyderabad  2017-04-19          Sunrisers Hyderabad
# 35    36    2017  Hyderabad  2017-04-30          Sunrisers Hyderabad
# 42    43    2017  Hyderabad  2017-05-06       Rising Pune Supergiant
# 46    47    2017  Hyderabad  2017-05-08               Mumbai Indians
# 58    59    2017  Hyderabad  2017-05-21               Mumbai Indians
# 65    66    2008  Hyderabad  2008-04-22              Deccan Chargers
# 67    68    2008  Hyderabad  2008-04-24              Deccan Chargers
# 76    77    2008  Hyderabad  2008-05-01              Deccan Chargers
# 79    80    2008  Hyderabad  2008-05-25              Deccan Chargers
# 91    92    2008  Hyderabad  2008-05-11        Kolkata Knight Riders
# ...

# %%
data[mask].count
# Out:
# <bound method DataFrame.count of       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 5      6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 18    19    2017  Hyderabad  2017-04-17          Sunrisers Hyderabad
# 20    21    2017  Hyderabad  2017-04-19          Sunrisers Hyderabad
# 35    36    2017  Hyderabad  2017-04-30          Sunrisers Hyderabad
# 42    43    2017  Hyderabad  2017-05-06       Rising Pune Supergiant
# 46    47    2017  Hyderabad  2017-05-08               Mumbai Indians
# 58    59    2017  Hyderabad  2017-05-21               Mumbai Indians
# 65    66    2008  Hyderabad  2008-04-22              Deccan Chargers
# 67    68    2008  Hyderabad  2008-04-24              Deccan Chargers
# 76    77    2008  Hyderabad  2008-05-01              Deccan Chargers
# 79    80    2008  Hyderabad  2008-05-25              Deccan Chargers
# ...

# %%
data[mask].shape
# Out:
# (49, 18)

# %%
data[mask].shape[0]
# Out:
# 49

# %%
#creating/defining a funtion
def get_city_match_count(city):                      #no of matches in a given city
    mask=data['city']==city                          #given by user
    return data[mask].shape[0]

# %%
get_city_match_count('Bangalore')
# Out:
# 66

# %%
get_city_match_count('Rajkot')
# Out:
# 10

# %%
mask2=data['date']>'2010-01-01'
mask2
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
#        ...
# 606    True
# 607    True
# 608    True
# 609    True
# 610    True
# 611    True
# 612    True
# 613    True
# 614    True
# 615    True
# 616    True
# 617    True
# 618    True
# 619    True
# 620    True
# 621    True
# 622    True
# 623    True
# 624    True
# 625    True
# 626    True
# 627    True
# 628    True
# 629    True
# 630    True
# 631    True
# 632    True
# 633    True
# 634    True
# 635    True
# Name: date, Length: 636, dtype: bool

# %%
mask1=data['city']=='Hyderabad'
mask2=data['date']>'2010-01-01'
data[mask1 & mask2]                            #used boolean/bitwise and instead of normal and operator as boolean values are held within it....
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 5      6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 18    19    2017  Hyderabad  2017-04-17          Sunrisers Hyderabad
# 20    21    2017  Hyderabad  2017-04-19          Sunrisers Hyderabad
# 35    36    2017  Hyderabad  2017-04-30          Sunrisers Hyderabad
# 42    43    2017  Hyderabad  2017-05-06       Rising Pune Supergiant
# 46    47    2017  Hyderabad  2017-05-08               Mumbai Indians
# 58    59    2017  Hyderabad  2017-05-21               Mumbai Indians
# 235  236    2011  Hyderabad  2011-04-09              Deccan Chargers
# 244  245    2011  Hyderabad  2011-04-14              Deccan Chargers
# 248  249    2011  Hyderabad  2011-04-16              Deccan Chargers
# 259  260    2011  Hyderabad  2011-04-24               Mumbai Indians
# 274  275    2011  Hyderabad  2011-05-03        Kolkata Knight Riders
# ...

# %%
data[mask1 & mask2].shape[0]
# Out:
# 42

# %%
data[mask1 & mask2].shape
# Out:
# (42, 18)

# %%
#The value_count() function
#two types of datasets/data:
    #categorical-categories
        #season column in this dataset can be categorised into various categories and all data are not unique
    #numerical-numeric data
        #id column for example contains unique data and cannot be categorised
#Generally value_count() function is generally used for categorical data/columns
#value_count() works only on series
data['winner'].value_counts()
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
#here
    #index=team name
    #value=matches won

# %%
#the plot function in pandas
#the Pandas Plot()

# %%
#data visualization libraries
    #matplotlib
    #seaborn
    #tableau
    #plotly
    #dash

# %%
#using pandas plot() function graphs can be used to determine and draw/sketch various graphs
#official documentation of pandas plot() funtion :- 
#https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.plot.html

#plotting bar chart
    #can be used for displaying/conveying 2 types of information
        #x-axis contains-categorical variable
            #in this dataset every team can be a category
        #y-axis contains-generally count/numeric data for a particular category/categorical data
            #in this dataset count of teams for example

# %%
data['winner'].value_counts()
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
#calling plot function on a series
import matplotlib.pyplot as plt
data['winner'].value_counts().plot(kind='bar')

# %%
#only for top 5 teams
data['winner'].value_counts().head()
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Name: winner, dtype: int64

# %%
data['winner'].value_counts().head().plot(kind='bar')

# %%
data['winner'].value_counts().head().plot(kind='barh')
#horizontal bar graph

# %%
#in horizontal bar graph categorical data moves to y-axis and vice-versa

# %%
#pie charts
data['toss_decision'].value_counts()              #series
# Out:
# field    363
# bat      273
# Name: toss_decision, dtype: int64

# %%
data['toss_decision'].value_counts().plot(kind='pie')

# %%
#histograms
#used to represent numeric values
#bins/intervals are created , values b/w 0-10,10,20,etc... and using this piece of information graph is plotted
#the purpose that solves bar graph for categorical data ,histogram does it for numeric data;that's it....
data['win_by_runs'].plot(kind='hist')

# %%
#Series operation
#series are the building blocks of dataframe

type(data['winner'].value_counts())
# Out:
# pandas.core.series.Series

# %%
#terminologies related to series
    #left part is the index and must be/is unique
    #right part is the vale of the index and can repeat or may not be unique
    
myseries=data['winner'].value_counts()

# %%
myseries
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
myseries.index
# Out:
# Index(['Mumbai Indians', 'Chennai Super Kings', 'Kolkata Knight Riders',
#        'Royal Challengers Bangalore', 'Kings XI Punjab', 'Rajasthan Royals',
#        'Delhi Daredevils', 'Sunrisers Hyderabad', 'Deccan Chargers',
#        'Gujarat Lions', 'Pune Warriors', 'Rising Pune Supergiant',
#        'Kochi Tuskers Kerala', 'Rising Pune Supergiants'],
#       dtype='object')

# %%
myseries.values
# Out:
# array([92, 79, 77, 73, 70, 63, 62, 42, 29, 13, 12, 10,  6,  5],
#       dtype=int64)

# %%
#.values,.head are hhe attributes
#used for extracting either the index or values respeectively inn form of array

# %%
#.head() and .tail() can also be used

myseries.tail()
# Out:
# Gujarat Lions              13
# Pune Warriors              12
# Rising Pune Supergiant     10
# Kochi Tuskers Kerala        6
# Rising Pune Supergiants     5
# Name: winner, dtype: int64

# %%
myseries.head()
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Name: winner, dtype: int64

# %%
#values against a particular index can also be extracted
myseries['Royal Challengers Bangalore']
# Out:
# 73

# %%
#fetching values against a specific index
myseries
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
myseries['Kings XI Punjab']
# Out:
# 70

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data['team1'].value_counts()
# Out:
# Mumbai Indians                 82
# Chennai Super Kings            77
# Kings XI Punjab                77
# Royal Challengers Bangalore    70
# Kolkata Knight Riders          68
# Delhi Daredevils               63
# Rajasthan Royals               54
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  14
# Rising Pune Supergiant          8
# Rising Pune Supergiants         7
# Kochi Tuskers Kerala            7
# Name: team1, dtype: int64

# %%
data['team2'].value_counts()
# Out:
# Delhi Daredevils               84
# Royal Challengers Bangalore    82
# Kolkata Knight Riders          80
# Mumbai Indians                 75
# Kings XI Punjab                71
# Rajasthan Royals               64
# Chennai Super Kings            54
# Deccan Chargers                32
# Sunrisers Hyderabad            30
# Pune Warriors                  26
# Gujarat Lions                  16
# Rising Pune Supergiant          8
# Rising Pune Supergiants         7
# Kochi Tuskers Kerala            7
# Name: team2, dtype: int64

# %%
#combining two series on the basis of their index
#two series having the same index number
data['team2'].value_counts()+data['team1'].value_counts()
# Out:
# Chennai Super Kings            131
# Deccan Chargers                 75
# Delhi Daredevils               147
# Gujarat Lions                   30
# Kings XI Punjab                148
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          148
# Mumbai Indians                 157
# Pune Warriors                   46
# Rajasthan Royals               118
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    152
# Sunrisers Hyderabad             76
# dtype: int64

# %%
#any other mathematical operation could have been performed be it*,/,etc
#comparisn operation can also be performed provided that both the series having the same index

data['team2'].value_counts()*data['team1'].value_counts()
# Out:
# Chennai Super Kings            4158
# Deccan Chargers                1376
# Delhi Daredevils               5292
# Gujarat Lions                   224
# Kings XI Punjab                5467
# Kochi Tuskers Kerala             49
# Kolkata Knight Riders          5440
# Mumbai Indians                 6150
# Pune Warriors                   520
# Rajasthan Royals               3456
# Rising Pune Supergiant           64
# Rising Pune Supergiants          49
# Royal Challengers Bangalore    5740
# Sunrisers Hyderabad            1380
# dtype: int64

# %%
data['team2'].value_counts()/data['team1'].value_counts()
# Out:
# Chennai Super Kings            0.701299
# Deccan Chargers                0.744186
# Delhi Daredevils               1.333333
# Gujarat Lions                  1.142857
# Kings XI Punjab                0.922078
# Kochi Tuskers Kerala           1.000000
# Kolkata Knight Riders          1.176471
# Mumbai Indians                 0.914634
# Pune Warriors                  1.300000
# Rajasthan Royals               1.185185
# Rising Pune Supergiant         1.000000
# Rising Pune Supergiants        1.000000
# Royal Challengers Bangalore    1.171429
# Sunrisers Hyderabad            0.652174
# dtype: float64

# %%
#The sort_values() method

# %%
(data['team2'].value_counts()+data['team1'].value_counts()).head()
# Out:
# Chennai Super Kings    131
# Deccan Chargers         75
# Delhi Daredevils       147
# Gujarat Lions           30
# Kings XI Punjab        148
# dtype: int64

# %%
#function for sorting
#sort_values()
#by default sorts in ascending order
(data['team2'].value_counts()+data['team1'].value_counts()).sort_values()
# Out:
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Rising Pune Supergiant          16
# Gujarat Lions                   30
# Pune Warriors                   46
# Deccan Chargers                 75
# Sunrisers Hyderabad             76
# Rajasthan Royals               118
# Chennai Super Kings            131
# Delhi Daredevils               147
# Kings XI Punjab                148
# Kolkata Knight Riders          148
# Royal Challengers Bangalore    152
# Mumbai Indians                 157
# dtype: int64

# %%
(data['team2'].value_counts()+data['team1'].value_counts()).sort_values().head()
# Out:
# Kochi Tuskers Kerala       14
# Rising Pune Supergiants    14
# Rising Pune Supergiant     16
# Gujarat Lions              30
# Pune Warriors              46
# dtype: int64

# %%
(data['team2'].value_counts()+data['team1'].value_counts()).sort_values().tail()
# Out:
# Delhi Daredevils               147
# Kings XI Punjab                148
# Kolkata Knight Riders          148
# Royal Challengers Bangalore    152
# Mumbai Indians                 157
# dtype: int64

# %%
(data['team2'].value_counts()+data['team1'].value_counts()).sort_values(ascending=False)
#alternate for .head() or .tail()
# Out:
# Mumbai Indians                 157
# Royal Challengers Bangalore    152
# Kolkata Knight Riders          148
# Kings XI Punjab                148
# Delhi Daredevils               147
# Chennai Super Kings            131
# Rajasthan Royals               118
# Sunrisers Hyderabad             76
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Kochi Tuskers Kerala            14
# dtype: int64

# %%
data
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 5      6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6      7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 7      8    2017         Indore  2017-04-10  Royal Challengers Bangalore
# 8      9    2017           Pune  2017-04-11             Delhi Daredevils
# 9     10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 10    11    2017        Kolkata  2017-04-13              Kings XI Punjab
# 11    12    2017      Bangalore  2017-04-14  Royal Challengers Bangalore
# ...

# %%
#sort_values() funtion operation on DataFrame
#sorting on the basis of sort

#sorted data in descending order
#the changes made here are not permanent
#in python if data/result is displayed on screen then the change in not permmanent
#and if not then the changes are permanent

data.sort_values('city',ascending=False)
# Out:
#       id  season           city        date                        team1  \
# 312  313    2012  Visakhapatnam  2012-04-07          Chennai Super Kings
# 622  623    2016  Visakhapatnam  2016-05-15               Mumbai Indians
# 615  616    2016  Visakhapatnam  2016-05-10          Sunrisers Hyderabad
# 612  613    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 624  625    2016  Visakhapatnam  2016-05-17             Delhi Daredevils
# 536  537    2015  Visakhapatnam  2015-04-22          Sunrisers Hyderabad
# 530  531    2015  Visakhapatnam  2015-04-18             Delhi Daredevils
# 528  529    2015  Visakhapatnam  2015-04-16          Sunrisers Hyderabad
# 628  629    2016  Visakhapatnam  2016-05-21              Kings XI Punjab
# 618  619    2016  Visakhapatnam  2016-05-13               Mumbai Indians
# 315  316    2012  Visakhapatnam  2012-04-09              Deccan Chargers
# 473  474    2014        Sharjah  2014-04-27          Sunrisers Hyderabad
# ...

# %%
data
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 5      6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6      7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 7      8    2017         Indore  2017-04-10  Royal Challengers Bangalore
# 8      9    2017           Pune  2017-04-11             Delhi Daredevils
# 9     10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 10    11    2017        Kolkata  2017-04-13              Kings XI Punjab
# 11    12    2017      Bangalore  2017-04-14  Royal Challengers Bangalore
# ...

# %%
#for making the changes permanent
#parameter :-inpalce with default value false

data.sort_values('city',ascending=False,inplace=True)

# %%
data
#caution:permanent data change will take place in dataset
# Out:
#       id  season           city        date                        team1  \
# 312  313    2012  Visakhapatnam  2012-04-07          Chennai Super Kings
# 622  623    2016  Visakhapatnam  2016-05-15               Mumbai Indians
# 615  616    2016  Visakhapatnam  2016-05-10          Sunrisers Hyderabad
# 612  613    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 624  625    2016  Visakhapatnam  2016-05-17             Delhi Daredevils
# 536  537    2015  Visakhapatnam  2015-04-22          Sunrisers Hyderabad
# 530  531    2015  Visakhapatnam  2015-04-18             Delhi Daredevils
# 528  529    2015  Visakhapatnam  2015-04-16          Sunrisers Hyderabad
# 628  629    2016  Visakhapatnam  2016-05-21              Kings XI Punjab
# 618  619    2016  Visakhapatnam  2016-05-13               Mumbai Indians
# 315  316    2012  Visakhapatnam  2012-04-09              Deccan Chargers
# 473  474    2014        Sharjah  2014-04-27          Sunrisers Hyderabad
# ...

# %%
#till now sorting was done either on a series or on a single column of a dataframe

# %%
#sorting multiple columns
#sorting on the basis of putting sort values on multiple columns

# %%
#sorting dataframe on the basis of city and date
#sorting on the basis of city and are also arranged date wise

# %%
#this time instead of providing a string , a list will be provided
data.sort_values(['city','date'])
#here city and dates are inn ascending order
# Out:
#       id  season           city        date                        team1  \
# 457  458    2014      Abu Dhabi  2014-04-16        Kolkata Knight Riders
# 460  461    2014      Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# 459  460    2014      Abu Dhabi  2014-04-18          Chennai Super Kings
# 464  465    2014      Abu Dhabi  2014-04-21          Chennai Super Kings
# 471  472    2014      Abu Dhabi  2014-04-26              Kings XI Punjab
# 470  471    2014      Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 475  476    2014      Abu Dhabi  2014-04-29             Rajasthan Royals
# 179  180    2010      Ahmedabad  2010-03-15             Rajasthan Royals
# 186  187    2010      Ahmedabad  2010-03-20             Rajasthan Royals
# 194  195    2010      Ahmedabad  2010-03-26              Deccan Chargers
# 197  198    2010      Ahmedabad  2010-03-28             Rajasthan Royals
# 481  482    2014      Ahmedabad  2014-05-05             Rajasthan Royals
# ...

# %%
#city in ascending order and date in descending order
data.sort_values(['city','date'],ascending=[True,False])
# Out:
#       id  season           city        date                        team1  \
# 475  476    2014      Abu Dhabi  2014-04-29             Rajasthan Royals
# 471  472    2014      Abu Dhabi  2014-04-26              Kings XI Punjab
# 470  471    2014      Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 464  465    2014      Abu Dhabi  2014-04-21          Chennai Super Kings
# 460  461    2014      Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# 459  460    2014      Abu Dhabi  2014-04-18          Chennai Super Kings
# 457  458    2014      Abu Dhabi  2014-04-16        Kolkata Knight Riders
# 539  540    2015      Ahmedabad  2015-04-24             Rajasthan Royals
# 535  536    2015      Ahmedabad  2015-04-21             Rajasthan Royals
# 532  533    2015      Ahmedabad  2015-04-19          Chennai Super Kings
# 525  526    2015      Ahmedabad  2015-04-14               Mumbai Indians
# 500  501    2014      Ahmedabad  2014-05-19               Mumbai Indians
# ...

# %%
#sort_values()
    #works on both series and dataframes
    #can be used for both ascending annd descending order
    #on dataframes both single and multiple columns can be sorted out

# %%
#The  drop_duplicate() funtion

# %%
data
# Out:
#       id  season           city        date                        team1  \
# 312  313    2012  Visakhapatnam  2012-04-07          Chennai Super Kings
# 622  623    2016  Visakhapatnam  2016-05-15               Mumbai Indians
# 615  616    2016  Visakhapatnam  2016-05-10          Sunrisers Hyderabad
# 612  613    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 624  625    2016  Visakhapatnam  2016-05-17             Delhi Daredevils
# 536  537    2015  Visakhapatnam  2015-04-22          Sunrisers Hyderabad
# 530  531    2015  Visakhapatnam  2015-04-18             Delhi Daredevils
# 528  529    2015  Visakhapatnam  2015-04-16          Sunrisers Hyderabad
# 628  629    2016  Visakhapatnam  2016-05-21              Kings XI Punjab
# 618  619    2016  Visakhapatnam  2016-05-13               Mumbai Indians
# 315  316    2012  Visakhapatnam  2012-04-09              Deccan Chargers
# 473  474    2014        Sharjah  2014-04-27          Sunrisers Hyderabad
# ...

# %%
data1=pd.read_csv('matches.csv')

# %%
data1
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 5      6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6      7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 7      8    2017         Indore  2017-04-10  Royal Challengers Bangalore
# 8      9    2017           Pune  2017-04-11             Delhi Daredevils
# 9     10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 10    11    2017        Kolkata  2017-04-13              Kings XI Punjab
# 11    12    2017      Bangalore  2017-04-14  Royal Challengers Bangalore
# ...

# %%
data.drop_duplicates(subset=['city'])
#parameter:-subset
#passing a list onto the parameter subset namely city
# Out:
#       id  season            city        date                        team1  \
# 312  313    2012   Visakhapatnam  2012-04-07          Chennai Super Kings
# 473  474    2014         Sharjah  2014-04-27          Sunrisers Hyderabad
# 498  499    2014          Ranchi  2014-05-18          Chennai Super Kings
# 19    20    2017          Rajkot  2017-04-18  Royal Challengers Bangalore
# 560  561    2015          Raipur  2015-05-09          Sunrisers Hyderabad
# 531  532    2015            Pune  2015-04-18              Kings XI Punjab
# 152  153    2009  Port Elizabeth  2009-05-10               Mumbai Indians
# 219  220    2010          Nagpur  2010-04-12              Deccan Chargers
# 49    50    2017          Mumbai  2017-05-11              Kings XI Punjab
# 212  213    2010         Kolkata  2010-04-07        Kolkata Knight Riders
# 236  237    2011           Kochi  2011-04-09         Kochi Tuskers Kerala
# 154  155    2009       Kimberley  2009-05-11              Deccan Chargers
# ...

# %%
data1.drop_duplicates(subset=['city'])
# Out:
#       id  season            city        date                        team1  \
# 0      1    2017       Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017            Pune  2017-04-06               Mumbai Indians
# 2      3    2017          Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017          Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017       Bangalore  2017-04-08  Royal Challengers Bangalore
# 6      7    2017          Mumbai  2017-04-09        Kolkata Knight Riders
# 10    11    2017         Kolkata  2017-04-13              Kings XI Punjab
# 14    15    2017           Delhi  2017-04-15             Delhi Daredevils
# 31    32    2017      Chandigarh  2017-04-28          Sunrisers Hyderabad
# 48    49    2017          Kanpur  2017-05-10                Gujarat Lions
# 64    65    2008          Jaipur  2008-04-21              Kings XI Punjab
# 66    67    2008         Chennai  2008-04-23          Chennai Super Kings
# ...

# %%
data1.drop_duplicates(subset=['city']).shape
# Out:
# (31, 18)

# %%
data.drop_duplicates(subset=['city']).shape
# Out:
# (31, 18)

# %%
data1.drop_duplicates(subset=['city'])
# Out:
#       id  season            city        date                        team1  \
# 0      1    2017       Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017            Pune  2017-04-06               Mumbai Indians
# 2      3    2017          Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017          Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017       Bangalore  2017-04-08  Royal Challengers Bangalore
# 6      7    2017          Mumbai  2017-04-09        Kolkata Knight Riders
# 10    11    2017         Kolkata  2017-04-13              Kings XI Punjab
# 14    15    2017           Delhi  2017-04-15             Delhi Daredevils
# 31    32    2017      Chandigarh  2017-04-28          Sunrisers Hyderabad
# 48    49    2017          Kanpur  2017-05-10                Gujarat Lions
# 64    65    2008          Jaipur  2008-04-21              Kings XI Punjab
# 66    67    2008         Chennai  2008-04-23          Chennai Super Kings
# ...

# %%
data1
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017           Pune  2017-04-06               Mumbai Indians
# 2      3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 5      6    2017      Hyderabad  2017-04-09                Gujarat Lions
# 6      7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 7      8    2017         Indore  2017-04-10  Royal Challengers Bangalore
# 8      9    2017           Pune  2017-04-11             Delhi Daredevils
# 9     10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 10    11    2017        Kolkata  2017-04-13              Kings XI Punjab
# 11    12    2017      Bangalore  2017-04-14  Royal Challengers Bangalore
# ...

# %%
#applying drop_duplicates() on multiple function
data1.drop_duplicates(subset=['city','season'])
# Out:
#       id  season            city        date                        team1  \
# 0      1    2017       Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017            Pune  2017-04-06               Mumbai Indians
# 2      3    2017          Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017          Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017       Bangalore  2017-04-08  Royal Challengers Bangalore
# 6      7    2017          Mumbai  2017-04-09        Kolkata Knight Riders
# 10    11    2017         Kolkata  2017-04-13              Kings XI Punjab
# 14    15    2017           Delhi  2017-04-15             Delhi Daredevils
# 31    32    2017      Chandigarh  2017-04-28          Sunrisers Hyderabad
# 48    49    2017          Kanpur  2017-05-10                Gujarat Lions
# 59    60    2008       Bangalore  2008-04-18        Kolkata Knight Riders
# 60    61    2008      Chandigarh  2008-04-19          Chennai Super Kings
# ...

# %%
data1.drop_duplicates(subset=['city','season']).shape
# Out:
# (107, 18)

# %%
#all the rows in which the value of city and season were repeating were terminated....
#no rows contain duplicate value of either city or season...
#operation is performed as if an AND operaion for both city annd season....

# %%
#application of drop_duplicates()
#winner of all 11 matches from when IPL started i.e from 2008 to 2017...
#hint:last match of the season is final match which decides the winner of the season....

# %%
data1.drop_duplicates('season')
# Out:
#       id  season       city        date                  team1  \
# 0      1    2017  Hyderabad  2017-04-05    Sunrisers Hyderabad
# 59    60    2008  Bangalore  2008-04-18  Kolkata Knight Riders
# 117  118    2009  Cape Town  2009-04-18         Mumbai Indians
# 174  175    2010     Mumbai  2010-03-12  Kolkata Knight Riders
# 234  235    2011    Chennai  2011-04-08    Chennai Super Kings
# 307  308    2012    Chennai  2012-04-04    Chennai Super Kings
# 381  382    2013    Kolkata  2013-04-03       Delhi Daredevils
# 457  458    2014  Abu Dhabi  2014-04-16  Kolkata Knight Riders
# 517  518    2015    Kolkata  2015-04-08         Mumbai Indians
# 576  577    2016     Mumbai  2016-04-09         Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 59   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
data1.drop_duplicates('season').shape
# Out:
# (10, 18)

# %%
data1.drop_duplicates('season',keep='last')
#by default drop_duplicates takes the value of keep as 1
#but here last one is required so it is necessary to explicitly specify it
#drop_duplicates application requires a li'l bit deep thinking and knowledge about the field in which analysis is done...
# Out:
#       id  season          city        date                team1  \
# 58    59    2017     Hyderabad  2017-05-21       Mumbai Indians
# 116  117    2008        Mumbai  2008-06-01  Chennai Super Kings
# 173  174    2009  Johannesburg  2009-05-24      Deccan Chargers
# 233  234    2010        Mumbai  2010-04-25  Chennai Super Kings
# 306  307    2011       Chennai  2011-05-28  Chennai Super Kings
# 380  381    2012       Chennai  2012-05-27  Chennai Super Kings
# 456  457    2013       Kolkata  2013-05-26       Mumbai Indians
# 516  517    2014     Bangalore  2014-06-01      Kings XI Punjab
# 575  576    2015       Kolkata  2015-05-24       Mumbai Indians
# 635  636    2016     Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 58        Rising Pune Supergiant               Mumbai Indians           bat
# 116             Rajasthan Royals             Rajasthan Royals         field
# ...

# %%
data1.drop_duplicates('season',keep='last').shape
# Out:
# (10, 18)

# %%
data1.drop_duplicates('season',keep='last')[['season','winner']]
# Out:
#      season                 winner
# 58     2017         Mumbai Indians
# 116    2008       Rajasthan Royals
# 173    2009        Deccan Chargers
# 233    2010    Chennai Super Kings
# 306    2011    Chennai Super Kings
# 380    2012  Kolkata Knight Riders
# 456    2013         Mumbai Indians
# 516    2014  Kolkata Knight Riders
# 575    2015         Mumbai Indians
# 635    2016    Sunrisers Hyderabad

# %%
data1.drop_duplicates('season',keep='last')[['season','winner']].sort_values('season')
# Out:
#      season                 winner
# 116    2008       Rajasthan Royals
# 173    2009        Deccan Chargers
# 233    2010    Chennai Super Kings
# 306    2011    Chennai Super Kings
# 380    2012  Kolkata Knight Riders
# 456    2013         Mumbai Indians
# 516    2014  Kolkata Knight Riders
# 575    2015         Mumbai Indians
# 635    2016    Sunrisers Hyderabad
# 58     2017         Mumbai Indians
